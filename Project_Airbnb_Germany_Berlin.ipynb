# %% [markdown]
# <center><img alt="Dbian Data Scientist" width="100%" src="data/Imagens/Dbianit.png"></center>

# %% [markdown]
# <img alt="Colaboratory logo" width="10%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# ###  Data Science na Prática 3.0**
#    - by [Dbian.io Data Scientist](https://www.linkedin.com/company/81834844/admin/)*
#
# ---

# %% [markdown]
# Concept:
#
# Airbnb allows individuals to rent all or part of their own home as a form of extra accommodation. The site provides a search and booking platform between the person offering the accommodation and the tourist looking for the rental. Covers over 500,000 ads in over 35,000 cities and 192 countries. From its inception in November 2008 to June 2012, more than 10 million bookings have been booked via Airbnb.# Análise dos Dados do Airbnb - *Germany/Berlin*
#
# O [Airbnb](https://www.airbnb.com.br/) is already considered to be the **biggest hotel company today**. Ah, the detail is that he **does not own any hotel**!
#
# It is a platform that connects people to properties listed on Airbnb. These properties can be private, hotels, inns and host, following Airbnb's rules and policy.
#
#
# The central objective is to connect people who want to travel (and stay) with hosts who want to rent their properties in a practical way, Airbnb provides an innovative platform to make this accommodation alternative.
#
# By the end of 2018, the Startup founded 10 years ago had already **hosted more than 300 million** people around the world, challenging traditional hotel chains.
#
# * Founders: Brian Chesky, Joe Gebbia e Nathan Blecharczyk
# * Thirst: São Francisco (Califórnia) USA
# * Ahrea(s) servida(s): World
# * Employees: 5,597 - survey done in (2020)
# * Services: Rental, Hospitality
#
# One of Airbnb's initiatives is to make website data available for some of the world's major cities. Through the [Inside Airbnb](http://insideairbnb.com/get-the-data.html) portal, it is possible to download a large amount of data to develop *Data Science* projects and solutions.
#
# <center><img alt="Analisando Airbnb" width="25%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>

# %% [markdown]
# <center><img alt="Berlin Germany" width="100%" src="data/Imagens/Berlin_germany.jpg"></center>

# %% [markdown]
# ### In this project I will work with data from Berlin Capital - Germany

# %% [markdown]
# Berlin (German: Berlin) is the capital and one of the sixteen states of Germany. With a population of 3.5 million within the city limits, it is the largest city in the country, and the seventh most populated urban area in the European Union. Situated in northeastern Germany, it is the center of the Berlin-Brandenburg metropolitan area, which includes 5 million people from over 190 nations. Located on the great European plain, Berlin is influenced by a temperate seasonal climate. About a third of the city's area is made up of forests, parks, gardens, rivers and lakes.
#
# First documented in the 13th century, Berlin was successively the capital of the Kingdom of Prussia (1701-1918), the German Empire (1871-1918), the Weimar Republic (1919-1933) and the Third Reich (1933-1945). After World War II, the city was divided; East Berlin became the capital of East Germany, while West Berlin became an exclave of West Germany, surrounded by the Berlin Wall, between the years 1961-1989; the city of Bonn became the capital of West Germany.
# After German reunification in 1990, the city regained its status as the capital of the Federal Republic of Germany, hosting 147 foreign embassies.
#
# Berlin is a global city and one of the world's most influential centers of culture, politics, media and science. Its economy is primarily based on the service sector, encompassing a diverse range of creative industries, media corporations and convention venues. Berlin also serves as a continental hub for air and rail transport and is a popular tourist destination. Significant industries include IT, pharmaceuticals, biomedical engineering, biotechnology, electronics, traffic engineering and renewable energy.
#
# The city serves as a major hub for continental transportation and is home to some of the most important universities, sporting events, orchestras and museums.
# The metropolis' rapid development has brought an international reputation to its festivals, contemporary architecture and nightlife, and it is a major tourist center and home to people from 180 different nations.
#
# ### Berlin's main neighborhoods
# * Friedrichshain, Kreuzberg, Mitte, Neukölln, Prenzlauer Berg Schöneberg, Zehlendorf

# %% [markdown]
# ## Neuschwanstein Castle: A Magic of Fairy Tales in Germany

# %% [markdown]
# <center><img alt="Berlin Germany" width="100%" src="data/Imagens/castelo_alemanha.jpg"></center>

# %% [markdown]
# # The history of Neuschwanstein Castle
# Neuschwanstein Castle was built in the second half of the 19th century, between the towns of Hohenschwangau and Füssen in southwest Bavaria, close to the division with Austria. It was conceived by Ludwig II of Bavaria, inspired by the work of a friend, the famous composer Richard Wagner. At the time, Ludwig II of Bavaria outlined in a letter the creation: of the building, saying the following
#
# It is my old intention to build a castle ruin at Hohenschwanga, in the true spirit of the old German knights' castles, in the true spirit of the old German knights' castles divine friend who brought salvation and true blessing to the world.
#
# * There are at least 12 more castles that everyone should know about.

# %% [markdown]
# ### Dictionary of variables (Pandas Profiling)
#
# # Variable e Decription
#
# * `id` - número de id gerado para identificar o imóvel
# * `name` - nome da propriedade anunciada
# * `host_id` - número de id do proprietário (anfitrião) da propriedade
# * `host_name` - Nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review - campo data - "y-m-d"
# * `reviews_per_month` - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
#
# Antes de iniciar qualquer análise, vamos verificar a cara do nosso *dataset*, analisando as 5 primeiras entradas.

# %% [markdown]
# ### Methodologies and tools used for this project
# * Python 3.9 and its most varied tools and libraries
# * Princípio Gestalt
# * Anaconda/JupyterLab
# * Methodology CRISP-DM; shearer-2000;
# * Supervised methods (i)
# * unsupervised methods (ii)

# %% [markdown]
# ### Libraries imported into the project

# %%
#Description of libraries

import pyforest 
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
import warnings
from datetime import datetime as dt

# Ignore alert warnings
warnings.filterwarnings('ignore')

# import refinitiv.dataplatform as rdp
# file_name = 'http://data.insideairbnb.com/germany/be/berlin/2021-12-17/visualisations/listings.csv'
# df = pd.read_csv(file_name)

# %% [markdown]
# ### Importing the Dataset

# %%
# Getting the Data 

file_path = (r'data/listings_irbnb_germany_berlin.csv')
df = pd.read_csv(file_path)

# file_path = open (r'data/listings_irbnb_germany_berlin.csv')
# df = pd.read_csv(file_path)
#                         #,parse_dates = True)
#                     #,index_col = 'iso_code')


# formatting decimals and scientific notation 
pd.set_option('display.float_format', '{:.4f}'.format)
# pd.set_option('display.float_format', lambda x: '%.0f' % x)

# formatting ... delimiter columns and rows
#pd.set_option('display.max_rows', None )# ou rows...)

# Checking dataset dimensions
print('Python print for me: ', 
          '\n\n''Dataset Dimensions(i-ii):',
          '\nVar dataset:',
          '\nEntries columns_var dimension:',
              df.shape[1], 
          '\nEntries input Line dimension:',
              df.shape[0])
# Out:
# Python print for me:
#
# Dataset Dimensions(i-ii):
# Var dataset:
# Entries columns_var dimension: 18
# Entries input Line dimension: 17290

# %% [markdown]
# ### Check and dimension of datetime and types

# %%
# Data Preparation

# Check datetime
# need to cast the date filed as datetime type
#format date para modelagem de médias móveis 

#Checking datetime format and transforming on input
df.last_review = pd.to_datetime(df.last_review)

#Pd.to.datetime treatment de object/string para format date
df.last_review = pd.to_datetime(df.last_review, format = "%Y-%m-%d")

#verificando a data dos primeiros e últimos registros (atemporal_date) bem como media dos meses median

print('Python print for me variable datetime transforming:','\n',
          '\nDataset datetime types','\n',
          '\nFirst records of data min: date:',
              df.last_review.min(), 
          '\nMean records of data meses: date:', 
              df.last_review.mean(),    
          '\nLast records of data max: date:',
              df.last_review.max())
               
print ('\nDatetime tranformed dtype:',
df.last_review.dtypes,'\n\n')

# Rading three lines
df.head(3)
# Out:
# Python print for me variable datetime transforming:
#
# Dataset datetime types
#
# First records of data min: date: 2012-07-08 00:00:00
# Mean records of data meses: date: 2020-02-10 23:04:43.549352192
# Last records of data max: date: 2021-12-17 00:00:00
#
# Datetime tranformed dtype: datetime64[ns]
#      id                                              name  host_id  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217
# 1  3176                   Fabulous Flat in great Location     3718
# 2  7071                  BrightRoom with sunny greenview!    17391
#
#     host_name neighbourhood_group            neighbourhood  latitude  \
# 0         Ion               Mitte          Brunnenstr. Süd   52.5331
# 1      Britta              Pankow  Prenzlauer Berg Südwest   52.5347
# 2  BrightRoom              Pankow           Helmholtzplatz   52.5430
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# ## Analysis of (variables) inputs and types

# %%
#Checking variáveis do df.
display(df.dtypes)
# Out:
# id                                         int64
# name                                      object
# host_id                                    int64
# host_name                                 object
# neighbourhood_group                       object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# price                                      int64
# minimum_nights                             int64
# number_of_reviews                          int64
# last_review                       datetime64[ns]
# reviews_per_month                        float64
# calculated_host_listings_count             int64
# availability_365                           int64
# number_of_reviews_ltm                      int64
# license                                   object
# dtype: object

# %%
# verificando o final do dataset
df.tail(3)
# Out:
#              id                                             name    host_id  \
# 17287  53844081  One-room apartment with a large private garden!  229695072
# 17288  53846012                Cute and cosy apartment in Berlin  326710801
# 17289  53847798      Cozy Studio Apartment near centre of Berlin  102805870
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 17287    Carlee               Mitte    Osloer Straße   52.5569    13.3953
# 17288  Wiktoria         Lichtenberg        Fennpfuhl   52.5289    13.4702
# 17289   Pribadi               Mitte  Wedding Zentrum   52.5414    13.3568
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 17287  Entire home/apt     60              92                  0         NaT
# 17288  Entire home/apt     26              12                  0         NaT
# 17289  Entire home/apt     80              28                  0         NaT
#
# ...

# %% [markdown]
# ### Percentage of missing values
#
# The quality of a *dataset* is directly related to the amount of missing values. It is important to understand early on whether these null values ​​are significant compared to the total entries.
#
# * You can see that the `licence` column has 100% of its values ​​missing.
# * The `reviews_per_month` and `last_review` variables have null values ​​on almost half of the rows.
# * The `name` and `host_name` variables have approximately 0.1% null values.

# %%
# sort variables in descending order by their missing values
#Checking missing data
pd.set_option('display.float_format','{:.4f}%'.format)  

print('Python print for me: ''\n',
          '\nChecking data missing please:','\n')
              
with pd.option_context('display.max_rows', (5), 'display.max_columns', None):
  print(((df.isnull().sum() / df.shape[0]) *100).sort_values(ascending = False))
# Out:
# Python print for me:
#
# Checking data missing please:
# license             75.5234%
# reviews_per_month   18.7854%
#                       ...
# host_id              0.0000%
# price                0.0000%
# Length: 18, dtype: float64

# %% [markdown]
# ## Delete values missing
#
# This is a first option when you are dealing with null values ​​of type `NaN` in your *DataFrame*.
#
# However, it tends to be less than ideal, because because of the value of a single cell, you eliminate existing data in other columns. This option should be considered in case the amount of null data is small to the point of not having representation in the dataset
#
# I can delete both rows with missing values ​​and entire columns. In order for Pandas to know if your intention is to drop rows (`axis=0`) or columns (`axis=1`), you must inform it within the `dropna()` method.

# %% [markdown]
# ## Fill in missing values
#
# This is usually the best option as it allows you to keep existing data in other cells.
#
# A question that usually comes up is: "but I replace the missing value with what value?". The answer to that question is: it depends.
#
# There are simple techniques such as using most frequent value, mean and median, as well as more advanced techniques that even involve the use of *machine learning* models whose function is to tell which value to use in these fields.
#
# I'll show you how you can use the median to fill the missing fields of the `ride_duration` column, using the `fillna()` function

# %%
#Creating dataset backup
df_clean = df.copy()

#eliminate all entries where there are missing values in `user_gender`
df_clean = df.dropna(subset=['license', 
                             'reviews_per_month',
                             'last_review'], axis=0) # Eixo = 0 linhas / Eixo = 1 Colmns

#Python compare before and after cleaning - print dataset values and percentage
print('Python print for me:\n',
          '\nChecking data missing please:')
print("Antes:\t{}".format(df.shape))
print("Depois:\t{}".format(df_clean.shape))

#comparing the before and after in percentage of missing values
pd.set_option('display.float_format','{:.4f}%'.format)                   
with pd.option_context('display.max_rows', (0), 'display.max_columns', None):
  print('\n''Percentile difference for me:'),
((df_clean.shape[0] / df.shape[0]*100))
# Out:
# Python print for me:
#
# Checking data missing please:
# Antes:	(17290, 18)
# Depois:	(3671, 18)
# Percentile difference for me:
# 21.231925968768074

# %%
#missing date arrival
df_clean.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %% [markdown]
# ### Intent of outliers and prices, comparing distribution with data from original dataset and clean dataset

# %%
#Function created for post-treatment analysis of data and visualization of outliers
#Cheking Outliers and prices per nigths

def gs(axx, dSet, c_x, c_y, stitle, n):
  sns.boxplot(x = dSet, whis = n, ax = axx)
  axx.text(c_x, c_y, stitle, fontsize = 20)
  axx.spines['top'].set_visible(False)
  axx.spines['right'].set_visible(False)
  axx.spines['left'].set_visible(True)
  axx.set_yticklabels(labels = [], visible = False)
  axx.set_yticks(ticks = [])

#Graphic "Boxplot" chart for analysis of average nightly price and ads
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18, 3), dpi = 75)
gs(ax1, df.price, 0, -0.6, 'Price per nights', None)
ax1.text(-1.0, -1.0, 'Price per minimum nigths', fontsize = 25);
gs(ax2, df.minimum_nights, 0, -0.6, 'Minimum nights per advertisements', None)
ax2.text(-1.0, -1.0, 'Outliers', fontsize = 25);

# %% [markdown]
# ### After cleaning dataset

# %%
#Function created for post-treatment analysis of data and visualization of outliers
#Cheking Outliers and prices per nigths

def gs(axx, dSet, c_x, c_y, stitle, n):
  sns.boxplot(x = dSet, whis = n, ax = axx)
  axx.text(c_x, c_y, stitle, fontsize = 20)
  axx.spines['top'].set_visible(False)
  axx.spines['right'].set_visible(False)
  axx.spines['left'].set_visible(True)
  axx.set_yticklabels(labels = [], visible = False)
  axx.set_yticks(ticks = [])

#Graphic "Boxplot" chart for analysis of average nightly price and ads
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (17, 3), dpi = 75)
gs(ax1, df_clean.price, 0, -0.6, 'Price per nights', None)
ax1.text(-1.0, -1.0, 'Price per minimum nigths', fontsize = 25);
gs(ax2, df_clean.minimum_nights, 0, -0.6, 'Minimum nights per advertisements', None)
ax2.text(-1.0, -1.0, 'Outliers', fontsize = 25);

# %% [markdown]
# ### Distribution of variables by clean base type

# %%
#plot the histogram of numeric variables
df_clean.hist(bins=15, figsize=(20, 15), grid = False);
plt.tight_layout()

# %% [markdown]
# ### Cheking se há *outliers* presentes
# By the distribution of the histogram, it is possible to verify evidence of the presence of *outliers*. Take for example the variables `price`, `minimum_nights` e `calculated_host_listings_count`.
#
# The values ​​do not follow a distribution, and they distort the entire graphical representation. To confirm, there are two quick ways that help detect *outliers*. Are they:
#
# * Statistical summary through the method `describe()`
# * Plot `boxplots` to variable
#
# ## Cleaning outliers for analysis
#
# To address the outliers of this dataset, we will analyze the statistical distribution, plot boxplots and calculate the limits using the IQR Score rule.
#
# Concept: First, let's remember what the IQR is and how it will be applied;
#
# The IQR is calculated by subtracting the Third Quartile (75%) from the First Quartile (25%):
#
# # IQR = Q3 - Q1
#
# ## Let's take a look at our data and see what we've identified.

# %%
#identifying outliers for the price variable
q1_price = df_clean.price.quantile(.25)
q3_price = df_clean.price.quantile(.75)
IQR_price = q3_price - q1_price
print('Python print for me:''\n'),
print('Interquartile range dimensions IQR:',
      '\n\nIQR = VALIABLES PRICE MEAN: ', IQR_price)

# definindo os limites                                       
sup_price = q3_price + 1.5 * IQR_price
inf_price = q1_price - 1.5 * IQR_price

print('price limit Upper : ', sup_price)
print('price limit Lower: ', inf_price)
# Out:
# Python print for me:
#
# Interquartile range dimensions IQR:
#
# IQR = VALIABLES PRICE MEAN:  65.0
# price limit Upper :  215.5
# price limit Lower:  -44.5

# %%
# statistical summary of numerical variables original dataset
pd.set_option('display.float_format','{:.3f}'.format)  
df[['price', 
    'minimum_nights', 
    'number_of_reviews', 
    'reviews_per_month',
    'calculated_host_listings_count', 
    'availability_365']].describe().round(0).T
# Out:
#                                    count   mean     std   min    25%    50%  \
# price                          17290.000 75.000 141.000 0.000 35.000 55.000
# minimum_nights                 17290.000 10.000  36.000 1.000  2.000  3.000
# number_of_reviews              17290.000 24.000  53.000 0.000  1.000  5.000
# reviews_per_month              14042.000  1.000   2.000 0.000  0.000  0.000
# calculated_host_listings_count 17290.000  3.000   7.000 1.000  1.000  1.000
# availability_365               17290.000 86.000 128.000 0.000  0.000  0.000
#
#                                    75%       max
# price                           85.000 10999.000
# minimum_nights                   5.000  1124.000
# number_of_reviews               19.000   916.000
# reviews_per_month                1.000    86.000
# calculated_host_listings_count   2.000    51.000
# availability_365               163.000   365.000

# %%
#create a correlation matrix method for kendall correlactions - Method: correlation kendall, spearman and pearon. 
kendall_corr = df[['price', 
                   'minimum_nights', 
                   'number_of_reviews', 
                   'reviews_per_month',
                   'calculated_host_listings_count', 
                   'availability_365']].corr('kendall') 
kendall_corr
# Out:
#                                 price  minimum_nights  number_of_reviews  \
# price                           1.000           0.005              0.082
# minimum_nights                  0.005           1.000             -0.056
# number_of_reviews               0.082          -0.056              1.000
# reviews_per_month               0.185          -0.119              0.659
# calculated_host_listings_count  0.177          -0.062              0.089
# availability_365                0.272           0.011              0.192
#
#                                 reviews_per_month  \
# price                                       0.185
# minimum_nights                             -0.119
# number_of_reviews                           0.659
# reviews_per_month                           1.000
# calculated_host_listings_count              0.216
# availability_365                            0.387
#
#                                 calculated_host_listings_count  \
# ...

# %% [markdown]
# ### Analysis summary resumo estatístico above statistics, we can confirm some hypotheses such as:
#
# * The `price` variable has 75% of the value below 85, but its maximum value is 10999.
# * The minimum number of nights (`minimum_nights`) is above 365 days in the year.
# * Fact (`minimum_nights`) does not match reality.
# * "max" value is probably outliers
#
# ## FCA - Fact cause and action
# * Fact: discrepant values ​​of outliers, mainly the more expensive properties;
# * Cause: needing cleaning to better equalize the price, minimum_nights and reviews_per_month variables;
# * Action: treatment - standardize so that we can get a better understanding of real values.

# %%
#plot graph boxplot
fig, ax = plt.subplots(figsize=(15,3), dpi=72)
df.price.plot(kind='box', vert=False);
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.set_title('Dataset Original - Price')
plt.show()

# verificando o conjunto original
print('Python print for me list below:''\n'),
print('Python print for me average number of entries general: ''{}''\n'.format(df.shape[0]))
print('Python print for me average number of entries 45.00: ''{}'.format(len(df[df.price > 45.00])))
print('Python print for me the average percentage representing the total entries: ''{:.4f}%'.format((len(df[df.price > 45.00]) / df.shape[0])*100))

print('Python print for me average number of entries general: ''{}''\n'.format(df.shape[0]))
print('Python print for me average number of entries 160.00: ''{}'.format(len(df[df.price > 65.00])))
print('Python print for me the average percentage representing the total entries: ''{:.4f}%'.format((len(df[df.price > 65.00]) / df.shape[0])*100))
# Out:
# Python print for me list below:
#
# Python print for me average number of entries general: 17290
#
# Python print for me average number of entries 45.00: 10556
# Python print for me the average percentage representing the total entries: 61.0526%
# Python print for me average number of entries general: 17290
#
# Python print for me average number of entries 160.00: 6831
# Python print for me the average percentage representing the total entries: 39.5084%

# %%
###Exploring correlations with Target
df_clean.corr()['price'].sort_values(ascending=False)
# Out:
# price                             1.000
# calculated_host_listings_count    0.087
# availability_365                  0.067
# host_id                           0.031
# latitude                          0.027
# id                                0.014
# longitude                         0.007
# minimum_nights                   -0.009
# number_of_reviews_ltm            -0.021
# reviews_per_month                -0.022
# number_of_reviews                -0.032
# Name: price, dtype: float64

# %%
#identifying outliers for the minimum_nights variable
q1_minimum_nights = df_clean.minimum_nights.quantile(.25)
q3_minimum_nights = df_clean.minimum_nights.quantile(.75)
IQR_minimum_nights = q3_minimum_nights - q1_minimum_nights
print('Python print for me:''\n'),
print('IQR da variável minimum_nights: ', IQR_minimum_nights)

# definindo os limites                                       
sup_minimum_nights = q3_minimum_nights + 1.5 * IQR_minimum_nights
inf_minimum_nights = q1_minimum_nights - 1.5 * IQR_minimum_nights

print('Limite superior de minimum_nights: ', sup_minimum_nights)
print('Limite inferior de minimum_nights: ', inf_minimum_nights)
# Out:
# Python print for me:
#
# IQR da variável minimum_nights:  2.0
# Limite superior de minimum_nights:  7.0
# Limite inferior de minimum_nights:  -1.0

# %%
#plot graph boxplot
fig, ax = plt.subplots(figsize=(15,3), dpi=72)
df.minimum_nights.plot(kind='box', vert=False);
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.set_title('Dataset Original - minimum_nights')
plt.show()

# verificando o conjunto original
print('Python print for me:''\n'),
print('Python print for me number of entries general: ''{}''\n'.format(df.shape[0]))
print('Python print for me number of entries general acima de 335.5: ''{}''\n'.format(len(df[df.minimum_nights > 7.0])))
print('Python print for me number of entries general representam: ''{:.2f}% '.format((len(df[df.minimum_nights > 7.0]) / df.shape[0])*100))
# Out:
# Python print for me:
#
# Python print for me number of entries general: 17290
#
# Python print for me number of entries general acima de 335.5: 2618
#
# Python print for me number of entries general representam: 15.14%

# %%
#Dataset clean values > rule below
df_clean = df.copy()

df_clean.drop(df_clean[df_clean.price > 335.5].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.price == 0.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 12].index, axis=0, inplace=True)

print('Shape antes da limpeza: ', df.shape)
print('Shape após a limpeza: ',df_clean.shape)

#Descritivo do dataset depois da limpeza com quantidade de linhas, colunas e percentil que representa o df_clean
# print('Python print for me:''\n'),
# print('Shape antes da limpeza: ', df.shape)
# print('Shape após a limpeza: ',df_clean.shape)
# df_clean = (df_clean.shape[0] * 100) / df.shape[0]
# print('Percentil do dataset após limpeza e reestruturação: {:.3f}%'.format(df_clean))
# Out:
# Shape antes da limpeza:  (17290, 18)
# Shape após a limpeza:  (14924, 18)

# %%
#plot graph boxplot price
fig, ax = plt.subplots(figsize=(15,3), dpi=72)
df.price.plot(kind='box', vert=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.set_title('Dataset Original - price');
plt.show()

#re-plotting the original boxplot
print('Python print for me:''\n'),
print('The dataset has {} lines'.format(df.shape[0]))
print('{} Entries above 335.5'.format(len(df[df.price > 335.5])))
print('Represent {:.4f}% do dataset'.format((len(df[df.price > 335.5]) / df.shape[0])*100))
# Out:
# Python print for me:
#
# The dataset has 17290 lines
# 192 Entries above 335.5
# Represent 1.1105% do dataset

# %%
# #plot graph boxplot price
fig, ax = plt.subplots(figsize=(15,3), dpi=72)
df_clean.price.plot(kind='box', vert=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.set_title('Dataset clean  - price')
plt.show()
print('Python print for me:''\n'),
print('Original dimension rows: {}'.format(df.shape[0]))
print('Current dimension rows: {}'.format(df_clean.shape[0]))
# Out:
# Python print for me:
#
# Original dimension rows: 17290
# Current dimension rows: 14924

# %% [markdown]
# ### Distribution of variables after cleaning

# %%
#After clean
df_clean.hist(bins=15, figsize=(20,15), grid=False);
plt.tight_layout()

# %% [markdown]
# ### Descriptive for the analysis of treated and moramatized variables
#
# * Price variable is properly standardized and with values ​​within what would be something closer to reality
# * Minimum_nights was also standardized, bringing logical coherence

# %%
# Description of variables
pd.set_option('display.float_format','{:.4f}'.format)  
df_clean.describe().round(1).T
# Out:
#                                     count          mean            std  \
# id                             14924.0000 25630191.5000  15431251.2000
# host_id                        14924.0000 95036638.7000 109581457.7000
# latitude                       14924.0000       52.5000         0.0000
# longitude                      14924.0000       13.4000         0.1000
# price                          14924.0000       68.6000        47.5000
# minimum_nights                 14924.0000        2.9000         2.0000
# number_of_reviews              14924.0000       25.3000        55.7000
# reviews_per_month              12449.0000        0.8000         1.6000
# calculated_host_listings_count 14924.0000        2.7000         6.1000
# availability_365               14924.0000       77.8000       124.3000
# number_of_reviews_ltm          14924.0000        4.0000        14.1000
#
#                                      min           25%           50%  \
# ...

# %% [markdown]
# ### Descriptive analysis for numerical variables and how they are distributed

# %%
# Description of numeric variables
df_clean[['price', 
    'minimum_nights',
    'number_of_reviews',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365']].describe().T
# Out:
#                                     count    mean      std    min     25%  \
# price                          14924.0000 68.5599  47.5173 9.0000 35.0000
# minimum_nights                 14924.0000  2.9455   2.0472 1.0000  1.0000
# number_of_reviews              14924.0000 25.2939  55.6849 0.0000  1.0000
# reviews_per_month              12449.0000  0.7636   1.6419 0.0100  0.0800
# calculated_host_listings_count 14924.0000  2.6904   6.0851 1.0000  1.0000
# availability_365               14924.0000 77.8277 124.3386 0.0000  0.0000
#
#                                    50%      75%      max
# price                          55.0000  85.0000 333.0000
# minimum_nights                  2.0000   4.0000  12.0000
# number_of_reviews               5.0000  20.0000 916.0000
# reviews_per_month               0.2700   0.9000  85.8300
# calculated_host_listings_count  1.0000   2.0000  51.0000
# availability_365                0.0000 118.2500 365.0000

# %%
#create a correlation matrix method for kendall correlactions - Method: correlation kendall, spearman and pearon.
# Description of numeric correlation
kendall_corr= df_clean[['price', 
    'minimum_nights',
    'number_of_reviews',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365']].corr('kendall')
kendall_corr
# Out:
#                                 price  minimum_nights  number_of_reviews  \
# price                          1.0000          0.0296             0.0904
# minimum_nights                 0.0296          1.0000            -0.0174
# number_of_reviews              0.0904         -0.0174             1.0000
# reviews_per_month              0.1907         -0.1234             0.6658
# calculated_host_listings_count 0.1947         -0.1691             0.1243
# availability_365               0.2948         -0.1019             0.2437
#
#                                 reviews_per_month  \
# price                                      0.1907
# minimum_nights                            -0.1234
# number_of_reviews                          0.6658
# reviews_per_month                          1.0000
# calculated_host_listings_count             0.2484
# availability_365                           0.4338
#
#                                 calculated_host_listings_count  \
# ...

# %% [markdown]
# ### Berlin's main neighborhoods
# * Friedrichshain, Kreuzberg, Mitte, Neukölln, Prenzlauer Berg Schöneberg, Zehlendorf
# * Average rental prices in Berlin $ 68.55 para um mínimum nigths (2) mean $ 35.00
# * Euro value 5.54

# %%
print('List Below = Minimo de Noites/Ocupação/Média')
df_clean.minimum_nights.mean()
# Out:
# List Below = Minimo de Noites/Ocupação/Média
# 2.945456982042348

# %%
#ndicators of the minimum of nights with 30, 12, 4 and 2 nights, so that we can intercede the dynamics especially in Berlin - Germany
# **Closing 100 percent of occupations**

print('Python list below:''\n'),
print('Minimum_price: Valores acima de 9.00 Euros:')
print('Python print for me average number of entries: ''{}'.format(len(df_clean[df_clean.price >= 9.00])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df_clean[df_clean.price >= 9.00]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 68.00 Euros:')
print('Python print for me average number of entries: ''{}'.format(len(df_clean[df.price >= 68.55])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df_clean[df_clean.price >= 68.55]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 227 Euros:')
print('Python print for me average number of entries: ''{}'.format(len(df_clean[df.price >= 227])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df_clean[df_clean.price >= 227]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 333 Euros:')
print('Python print for me average number of entries: ''{}'.format(len(df_clean[df.price >= 333])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df_clean[df_clean.price >= 333]) / df.shape[0])*100))

df_clean.price.plot(kind='box', vert=False, figsize=(15, 3), grid=False)
plt.show()
# Out:
# Python list below:
#
# Minimum_price: Valores acima de 9.00 Euros:
# Python print for me average number of entries: 14924
# Python print for me average number of entries percentil: 86.3158%
# Minimum_Nights: Valores acima de 68.00 Euros:
# Python print for me average number of entries: 5738
# Python print for me average number of entries percentil: 33.1868%
# Minimum_Nights: Valores acima de 227 Euros:
# Python print for me average number of entries: 252
# Python print for me average number of entries percentil: 1.4575%
# Minimum_Nights: Valores acima de 333 Euros:
# Python print for me average number of entries: 1
# Python print for me average number of entries percentil: 0.0058%

# %% [markdown]
# ## Summary escriptive statistics by variable and importance
#
# Olhando o resumo estatístico acima, podemos confirmar algumas hipóteses como:
#
# * A variável `price` possui 75% do valor abaixo de 85000, porém seu valor máximo é 333.00.
# * A média ponderada da variável "price" ficou em 68.00 com media apontando para 55.00 e provavelmene dependendo do perfil do imóvel, com um mímimo de $ 9.00
# * A quantidade de minimum_nigths normatizada, ficou com um mínimo 2 duas noites e máximo 12 noites, algo mais dentro da realidade;
#
# #### Boxplot para minimum_nights

# %% [markdown]
# ### Taking into account the number of nights, minimum, average and maximum indicators

# %%
#ndicators of the minimum of nights with 30, 12, 4 and 2 nights, so that we can intercede the dynamics especially in Berlin - Germany
# **Closing 100 percent of occupations**

print('Python list below:''\n'),

print('Minimum_Nights: Valores acima de 2 dias nights:')
print('Python print for me average number of entries:''{}'.format(len(df[df.minimum_nights > 2])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df[df.minimum_nights > 2]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 4 dias nights:')
print('Python print for me average number of entries:''{}'.format(len(df[df.minimum_nights > 4])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df[df.minimum_nights > 4]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 12 dias nights:')
print('Python print for me average number of entries:''{}'.format(len(df[df.minimum_nights > 12])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df[df.minimum_nights > 12]) / df.shape[0])*100))
print('Minimum_Nights: Valores acima de 30 dias nights:')
print('Python print for me average number of entries:''{}'.format(len(df[df.minimum_nights > 30])))
print('Python print for me average number of entries percentil: ''{:.4f}%'.format((len(df[df.minimum_nights > 30]) / df.shape[0])*100))
df_clean.minimum_nights.plot(kind='box', vert=False, figsize=(15, 3), grid=False)
plt.show()
# Out:
# Python list below:
#
# Minimum_Nights: Valores acima de 2 dias nights:
# Python print for me average number of entries:9363
# Python print for me average number of entries percentil: 54.1527%
# Minimum_Nights: Valores acima de 4 dias nights:
# Python print for me average number of entries:5015
# Python print for me average number of entries percentil: 29.0052%
# Minimum_Nights: Valores acima de 12 dias nights:
# Python print for me average number of entries:2184
# Python print for me average number of entries percentil: 12.6316%
# Minimum_Nights: Valores acima de 30 dias nights:
# Python print for me average number of entries:1028
# Python print for me average number of entries percentil: 5.9456%

# %%
# Estatística das variáveis numéricas
df_clean[['price', 
    'minimum_nights',
    'number_of_reviews',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365']].describe().T
# Out:
#                                     count    mean      std    min     25%  \
# price                          14924.0000 68.5599  47.5173 9.0000 35.0000
# minimum_nights                 14924.0000  2.9455   2.0472 1.0000  1.0000
# number_of_reviews              14924.0000 25.2939  55.6849 0.0000  1.0000
# reviews_per_month              12449.0000  0.7636   1.6419 0.0100  0.0800
# calculated_host_listings_count 14924.0000  2.6904   6.0851 1.0000  1.0000
# availability_365               14924.0000 77.8277 124.3386 0.0000  0.0000
#
#                                    50%      75%      max
# price                          55.0000  85.0000 333.0000
# minimum_nights                  2.0000   4.0000  12.0000
# number_of_reviews               5.0000  20.0000 916.0000
# reviews_per_month               0.2700   0.9000  85.8300
# calculated_host_listings_count  1.0000   2.0000  51.0000
# availability_365                0.0000 118.2500 365.0000

# %%
#create a correlation matrix method for kendall correlactions - Method: correlation kendall, spearman and pearon.
# Description of numeric correlactions
kendall_corr= df_clean[['price', 
    'minimum_nights',
    'number_of_reviews',
    'reviews_per_month',
    'calculated_host_listings_count',
    'availability_365']].corr('kendall')
kendall_corr
# Out:
#                                 price  minimum_nights  number_of_reviews  \
# price                          1.0000          0.0296             0.0904
# minimum_nights                 0.0296          1.0000            -0.0174
# number_of_reviews              0.0904         -0.0174             1.0000
# reviews_per_month              0.1907         -0.1234             0.6658
# calculated_host_listings_count 0.1947         -0.1691             0.1243
# availability_365               0.2948         -0.1019             0.2437
#
#                                 reviews_per_month  \
# price                                      0.1907
# minimum_nights                            -0.1234
# number_of_reviews                          0.6658
# reviews_per_month                          1.0000
# calculated_host_listings_count             0.2484
# availability_365                           0.4338
#
#                                 calculated_host_listings_count  \
# ...

# %% [markdown]
# ### Conclusion about minimum Nights

# %% [markdown]
# ### Taking into account the descriptive analysis above, we can conclude that:
# * First, that the data were well treated;
# * The average occupancy of 2 nights with (54.1527%) followed by 4 nights with (29.0052%) and the rest was spread over 12 and 39 days, closing 100%

# %%
#sort variables in descending order by their missing values
((df_clean.isnull().sum() / df_clean.shape[0]).sort_values(ascending=False))
# Out:
# license                          0.7430
# reviews_per_month                0.1658
# last_review                      0.1658
# name                             0.0017
# host_name                        0.0007
# minimum_nights                   0.0000
# number_of_reviews_ltm            0.0000
# availability_365                 0.0000
# calculated_host_listings_count   0.0000
# number_of_reviews                0.0000
# id                               0.0000
# room_type                        0.0000
# longitude                        0.0000
# latitude                         0.0000
# neighbourhood                    0.0000
# neighbourhood_group              0.0000
# host_id                          0.0000
# price                            0.0000
# dtype: float64

# %% [markdown]
# ### Correlation between variables

# %%
#create a correlation matrix
matriz_corr = df_clean[['price',
                 'minimum_nights',
                 'number_of_reviews', 
                 'reviews_per_month', 
                 'calculated_host_listings_count',
                 'availability_365']].corr()
# mostrar a matriz de correlação
matriz_corr
# Out:
#                                  price  minimum_nights  number_of_reviews  \
# price                           1.0000         -0.0027             0.0865
# minimum_nights                 -0.0027          1.0000            -0.0992
# number_of_reviews               0.0865         -0.0992             1.0000
# reviews_per_month               0.1006         -0.1477             0.6202
# calculated_host_listings_count  0.2430         -0.1364             0.0722
# availability_365                0.3378         -0.1336             0.2717
#
#                                 reviews_per_month  \
# price                                      0.1006
# minimum_nights                            -0.1477
# number_of_reviews                          0.6202
# reviews_per_month                          1.0000
# calculated_host_listings_count             0.1299
# availability_365                           0.3133
#
#                                 calculated_host_listings_count  \
# ...

# %%
#heatmap of the correlation between the variables
sns.set(rc = {'figure.figsize':(10,5)})
sns.heatmap(matriz_corr, 
            cmap='RdBu', 
            fmt='.2f', 
            square=True, 
            linecolor= 'white', annot=True);

# %% [markdown]
# ### Most rented property type Airbnb profile Berlim
#
# * Below we can easily identify that the apartments far exceed the number of days with overnight stays and minimum nights per rental. However, it is nice to see that there are options for simpler rooms and rooms in high standard houses, true presidential suites. for rent, host and host family. It won't be for lack of options that we won't get to know Berlin, a beautiful city, as well as all other cities in Germany, in addition to the culture of course.

# %%
print('List Below = Minimo de Noites/Ocupação/Média')
df_clean.minimum_nights.mean()
# Out:
# List Below = Minimo de Noites/Ocupação/Média
# 2.945456982042348

# %%
#Average prices per room_type in Berlin
print('Python print for me:''\n'), 
print('Mean price from the room_type of belin:'),
pd.set_option('display.float_format','{:.3f}'.format)  
df_clean.groupby(['room_type']).price.mean().sort_values(ascending=False)[:10]
# Out:
# Python print for me:
#
# Mean price from the room_type of belin:
# room_type
# Hotel room        126.778
# Entire home/apt    88.730
# Private room       43.645
# Shared room        34.973
# Name: price, dtype: float64

# %%
#Graphic bar Average prices per room_type in Berlin
df_clean.groupby(['room_type']).price.mean().sort_values(ascending=False)[:10].plot.bar(figsize=(18, 5), title='Mean price from the room_type of belin', grid=False);
plt.xticks(rotation=0);

# %%
#Average prices per neighborhood in Berlin
print('Python print for me:''\n'), 
print('Mean price from the neighborhoods of belin:'),
pd.set_option('display.float_format','{:.3f}'.format)  
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# Python print for me:
#
# Mean price from the neighborhoods of belin:
# neighbourhood
# Haselhorst          199.091
# Spandau Mitte       124.400
# Müggelheim          118.091
# Allende-Viertel     108.000
# Regierungsviertel   107.871
# Heerstrasse         102.086
# Kurfürstendamm      100.865
# Brunnenstr. Süd      97.530
# Marzahn-Süd          96.045
# Wilhelmstadt         96.000
# Name: price, dtype: float64

# %%
#Average prices per neighborhood in Berlin
print('Python print for me:''\n'), 
print('Mean price from the neighborhoods of belin:'),
pd.set_option('display.float_format','{:.3f}'.format)  
df_clean.groupby(['neighbourhood']).price.max().sort_values(ascending=False)[:10]
# Out:
# Python print for me:
#
# Mean price from the neighborhoods of belin:
# neighbourhood
# nördliche Luisenstadt       333
# Prenzlauer Berg Süd         329
# Brunnenstr. Nord            327
# südliche Luisenstadt        326
# Allende-Viertel             326
# Regierungsviertel           324
# Brunnenstr. Süd             324
# Neuköllner Mitte/Zentrum    323
# Tempelhof                   322
# Westend                     320
# Name: price, dtype: int64

# %%
#Average prices per neighborhood in Berlin
print('Python print for me:''\n'), 
print('Mean price from the neighborhoods of belin:'),
pd.set_option('display.float_format','{:.3f}'.format)  
df_clean.groupby(['neighbourhood']).price.min().sort_values(ascending=False)[:10]
# Out:
# Python print for me:
#
# Mean price from the neighborhoods of belin:
# neighbourhood
# Malchow, Wartenberg und Falkenberg    82
# Buckow Nord                           45
# Marzahn-Süd                           40
# Rahnsdorf/Hessenwinkel                40
# Marzahn-Nord                          40
# Falkenhagener Feld                    38
# Forst Grunewald                       35
# West 5                                35
# Gatow / Kladow                        31
# Friedrichshagen                       30
# Name: price, dtype: int64

# %%
#Graphic number of properties available per profile
df_clean.room_type.value_counts().plot.bar(figsize=(18, 5), title='Mean per type prolile property', grid=False);
plt.xticks(rotation=0);
print('List Below = Qty by Property Type total:'' {} '.format(df_clean.shape[0]))
df_clean.room_type.value_counts()
# Out:
# List Below = Qty by Property Type total: 14924
# Entire home/apt    8017
# Private room       6580
# Shared room         183
# Hotel room          144
# Name: room_type, dtype: int64

# %%
# show the percentage of each property type available
pd.set_option('display.float_format','{:.4f}%'.format)  
print('Python print for me:'),
print('List Below:\n'),
print('Percentage of properties by type in Berlin total: ''{}' .format(df_clean.shape[0]))
df_clean.room_type.value_counts() / df_clean.shape[0]
# Out:
# Python print for me:
# List Below:
#
# Percentage of properties by type in Berlin total: 14924
# Entire home/apt   0.5372%
# Private room      0.4409%
# Shared room       0.0123%
# Hotel room        0.0096%
# Name: room_type, dtype: float64

# %% [markdown]
# ### Most expensive locale in the dataset - Germany Berlin

# %%
# show percentage of average prices by type and location 
print('pythonn print for me:\n'),
print('List Below = Location by type of property total: {}'.format(df_clean.shape[0]))
df_clean.groupby(['neighbourhood_group']).price.mean().sort_values(ascending = False)[0:5]
# Out:
# pythonn print for me:
#
# List Below = Location by type of property total: 14924
# neighbourhood_group
# Spandau                  91.9780%
# Mitte                    77.4431%
# Pankow                   73.9439%
# Charlottenburg-Wilm.     73.9438%
# Tempelhof - Schöneberg   68.6158%
# Name: price, dtype: float64

# %% [markdown]
# ### top 5 regions with the most expensive "average" price in the city of Berlin

# %%
#Graphick bar price mean expensive per regions
df_clean.groupby(['neighbourhood_group']).price.mean().sort_values(ascending = False)[0:5].plot.bar(figsize=(18, 5), fontsize=12, title='prices mean expensive per regions', grid=False)
plt.xticks(rotation=0);
plt.tight_layout()

# %% [markdown]
# ### top 5 most expensive "max" regions in the city of Berlin

# %%
df_clean.groupby(['neighbourhood_group']).price.max().sort_values(ascending = False)[0:5].plot.bar(figsize=(18, 5), fontsize=12, title='prices max expensive per regions', grid=False)
plt.xticks(rotation=0);
plt.tight_layout()

# %% [markdown]
# ### top 5 most expensive "min" per regions in the city of Berlin

# %%
df_clean.groupby(['neighbourhood_group']).price.min().sort_values(ascending = False)[0:5].plot.bar(figsize=(18, 5), fontsize=12, title='prices min expensive per regions', grid=False)
plt.xticks(rotation=0);
plt.tight_layout()

# %%
df_clean.hist(bins=15, figsize=(25, 15),  grid = False);
plt.tight_layout()

# %% [markdown]
# ### Geomarket map, city and Berlin properties with neighborhood location (lat, long) average and minimum nightly price on average that properties were occupied

# %%
#plot mapa de calor

df_clean [['neighbourhood_group',
               'number_of_reviews_ltm',
                   'availability_365',
                       'number_of_reviews',
                   'room_type',
                'price',
'minimum_nights']].copy()
fig = px.scatter_mapbox(df_clean,
                            hover_name= 
                                'neighbourhood_group',
                                 hover_data =
                                        ['minimum_nights'],
                                        lat=
                                        'latitude',
                                        lon=
                                        'longitude',
                                        color=
                                'price',
                                size = 
                                'price',          
color_discrete_sequence=['black','blue','red','magenta','orange'],
#color_continuous_scale=px.colors.cyclical.IceFire,
                            size_max=12,
                          zoom=10)
fig.update_layout(mapbox_style= "open-street-map")
# fig.update_layout(margin=dict(l=0, r=0, t=30, b=10))
fig.update_layout(height=300, margin={ "r" : 0 , "t" : 0 , "l" : 0 , "b" : 0 } ) 
fig.show()
# Out:
# <div>                            <div id="29b470b5-51bb-4d5a-a95f-d677a36a8907" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29b470b5-51bb-4d5a-a95f-d677a36a8907")) {                    Plotly.newPlot(                        "29b470b5-51bb-4d5a-a95f-d677a36a8907",                        [{"customdata":[[1],[6],[3],[2],[5],[3],[4],[3],[2],[10],[5],[2],[3],[1],[1],[4],[5],[3],[5],[3],[2],[6],[3],[3],[2],[4],[4],[1],[3],[3],[4],[5],[2],[2],[7],[1],[2],[3],[10],[1],[2],[5],[5],[7],[2],[5],[2],[1],[3],[3],[1],[3],[2],[2],[2],[7],[3],[4],[3],[1],[2],[3],[3],[3],[7],[3],[3],[7],[5],[7],[2],[2],[3],[2],[5],[3],[1],[4],[10],[2],[1],[5],[5],[3],[3],[10],[2],[3],[3],[3],[3],[4],[5],[2],[2],[1],[1],[2],[4],[2],[4],[1],[2],[3],[3],[3],[3],[1],[3],[3],[5],[3],
# ...

# %% [markdown]
# ### Static map of geolocation of properties with price scale

# %%
#graphic plot
df_clean.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8,
cmap=plt.get_cmap('jet'), figsize=(12,6),  fontsize=12, grid=False);
plt.tight_layout()

# %%
print('Dbian Technology For Business',
            '\nBlumenau - SC\n'),
print('\n''Claudio Fabian Stychnicki',
            '\n''Data Scientist''\n',
            '\n''Phone: (47) 9-92374737',
            '\n''Supplemental information on github and linkedIn''\n',
            '\n''Best regards;')
# Out:
# Dbian Technology For Business
# Blumenau - SC
#
#
# Claudio Fabian Stychnicki
# Data Scientist
#
# Phone: (47) 9-92374737
# Supplemental information on github and linkedIn
#
# Best regards;

# %% [markdown]
# ### Until the next project, thank you.
